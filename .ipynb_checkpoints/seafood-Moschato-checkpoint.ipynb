# %% [markdown]
# Moschato is a south-west coastal suburb in Athens, Greece. It is well known for its mid-priced seafood restaurants. The aim of this project is to generate a visualization of the competition in the area towards identifying a location for a new restaurant.

# %%
import requests        # library to handle API requests
import pandas as pd    # library for data analsysisprojectp
import numpy as np     # library to handle data in a vectorized manner
import folium          # plotting library

from geopy.geocoders import Nominatim       # module to convert an address into latitude and longitude values

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
CLIENT_ID = 'VVYPVIUVG44L3HD4NBFEGWZWEL2SNZLS2FSU4FN5KMWHTT3A'
CLIENT_SECRET = 'BIQ3R1HDU5Z2GL25TLDAPPP1BAWKBNPODJJAUMOR0PI4PWIZ'
VERSION = '20201201'

print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# CLIENT_ID: VVYPVIUVG44L3HD4NBFEGWZWEL2SNZLS2FSU4FN5KMWHTT3A
# CLIENT_SECRET:BIQ3R1HDU5Z2GL25TLDAPPP1BAWKBNPODJJAUMOR0PI4PWIZ

# %%
# Get 'Moschato' geolocation to be used for centerint the map
address = 'Moschato'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

print(latitude, longitude)
# Out:
# 37.9535099 23.681799

# %% [markdown]
# We will create an 'explore' API request to Foursquare.com for restaurants under the section 'food' and category 'seafood'. We will request the hit limit to be 100 in order to override the default (30).

# %%
area = 'Moschato'
section = 'food'
category = '4bf58dd8d48988d1ce941735'    # seafood category id
limit = 100

url = 'https://api.foursquare.com/v2/venues/explore?\
client_id={}&\
client_secret={}&\
near={}&v={}&\
section={}&\
categoryId={}&\
limit={}'\
.format(CLIENT_ID, CLIENT_SECRET, area, VERSION, section, category, limit)

url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=VVYPVIUVG44L3HD4NBFEGWZWEL2SNZLS2FSU4FN5KMWHTT3A&client_secret=BIQ3R1HDU5Z2GL25TLDAPPP1BAWKBNPODJJAUMOR0PI4PWIZ&near=Moschato&v=20201201&section=food&categoryId=4bf58dd8d48988d1ce941735&limit=100'

# %%
results = requests.get(url).json()
venues = results['response']['groups'][0]['items']
df = pd.json_normalize(venues)

df
# Out:
#                          referralId  reasons.count  \
# 0    e-3-513b9171e4b0dd4603da018f-0              0
# 1    e-3-4ccc7c39ee23a14395751fa8-1              0
# 2    e-3-4d1a5b038e4c548112f84abc-2              0
# 3    e-3-4b6dc50df964a5202e8e2ce3-3              0
# 4    e-3-521bac2e11d246593b15de20-4              0
# ..                              ...            ...
# 95  e-3-4e43953662e1b6355aa13845-95              0
# 96  e-3-56fc38a8498e2f8d5f35145a-96              0
# 97  e-3-4e0303786284217c7f114c0d-97              0
# 98  e-3-4d4ba48e8e948cfa1a12f348-98              0
# 99  e-3-4f77427be4b06ff83609293e-99              0
#
#                                         reasons.items  \
# 0   [{'summary': 'This spot is popular', 'type': '...
# 1   [{'summary': 'This spot is popular', 'type': '...
# 2   [{'summary': 'This spot is popular', 'type': '...
# 3   [{'summary': 'This spot is popular', 'type': '...
# 4   [{'summary': 'This spot is popular', 'type': '...
# ..                                                ...
# 95  [{'summary': 'This spot is popular', 'type': '...
# 96  [{'summary': 'This spot is popular', 'type': '...
# 97  [{'summary': 'This spot is popular', 'type': '...
# 98  [{'summary': 'This spot is popular', 'type': '...
# 99  [{'summary': 'This spot is popular', 'type': '...
#
#                     venue.id   venue.name    venue.location.address  \
# 0   513b9171e4b0dd4603da018f  Ψαρομεζέδες  Στρατηγού Μακρυγιάννη 34
# 1   4ccc7c39ee23a14395751fa8      Ο Βόλος              Πλάτωνος 110
# 2   4d1a5b038e4c548112f84abc      Άργουρα           Αγησιλάου 49-51
# 3   4b6dc50df964a5202e8e2ce3   Τα κανάρια                Κανάρη 119
# 4   521bac2e11d246593b15de20     Πιτόψωμο        Λάμπρου Κατσώνη 19
# ..                       ...          ...                       ...
# 95  4e43953662e1b6355aa13845         Άκρη   Παναγή Τσαλδάρη 261-263
# 96  56fc38a8498e2f8d5f35145a     Überness              Τζον Κένεντι
# 97  4e0303786284217c7f114c0d      REFRESH          Δοϊράνης 238-242
# 98  4d4ba48e8e948cfa1a12f348   Senso Cafe  Ελευθερίου Βενιζέλου 216
# 99  4f77427be4b06ff83609293e        Salty      Ακτή Κουμουνδούρου 1
#
#    venue.location.crossStreet  venue.location.lat  venue.location.lng  \
# 0                      Κανάρη           37.947742           23.677772
# 1                         NaN           37.950961           23.683292
# 2                         NaN           37.945695           23.686086
# 3                         NaN           37.946883           23.682486
# 4          Κωνσταντινουπόλεως           37.949126           23.674597
# ..                        ...                 ...                 ...
# 95                   Ιατρίδου           37.956954           23.694091
# 96                        NaN           37.960885           23.681433
# 97                        NaN           37.942133           23.696154
# 98                        NaN           37.948990           23.695177
# 99                Μικρολιμανο           37.938035           23.661673
#
#                         venue.location.labeledLatLngs  ... venue.location.cc  \
# 0   [{'label': 'display', 'lat': 37.94774206740425...  ...                GR
# 1   [{'label': 'display', 'lat': 37.95096101404494...  ...                GR
# 2   [{'label': 'display', 'lat': 37.94569542257485...  ...                GR
# 3   [{'label': 'display', 'lat': 37.946883248532, ...  ...                GR
# 4   [{'label': 'display', 'lat': 37.94912587271244...  ...                GR
# ..                                                ...  ...               ...
# 95  [{'label': 'display', 'lat': 37.95695423013006...  ...                GR
# 96  [{'label': 'display', 'lat': 37.96088460819474...  ...                GR
# 97  [{'label': 'display', 'lat': 37.94213289575703...  ...                GR
# 98  [{'label': 'display', 'lat': 37.94898978519051...  ...                GR
# 99  [{'label': 'display', 'lat': 37.93803549498863...  ...                GR
#
#      venue.location.city venue.location.state venue.location.country  \
# 0                Μοσχάτο               Αττική                 Ελλάδα
# 1                Μοσχάτο               Αττική                 Ελλάδα
# 2               Καλλιθέα               Αττική                 Ελλάδα
# 3                Μοσχάτο               Αττική                 Ελλάδα
# 4                Μοσχάτο               Αττική                 Ελλάδα
# ..                   ...                  ...                    ...
# 95              Καλλιθέα               Αττική                 Ελλάδα
# 96  Άγιος Ιωάννης Ρέντης               Αττική                 Ελλάδα
# 97              Καλλιθέα               Αττική                 Ελλάδα
# 98              Καλλιθέα               Αττική                 Ελλάδα
# 99              Πειραιάς               Αττική                 Ελλάδα
#
#                       venue.location.formattedAddress  \
# 0   [Στρατηγού Μακρυγιάννη 34 (Κανάρη), 183 44 Μοσ...
# 1      [Πλάτωνος 110, 183 45 Μοσχάτο, Αττική, Ελλάδα]
# 2   [Αγησιλάου 49-51, 176 75 Καλλιθέα, Αττική, Ελλ...
# 3        [Κανάρη 119, 183 44 Μοσχάτο, Αττική, Ελλάδα]
# 4   [Λάμπρου Κατσώνη 19 (Κωνσταντινουπόλεως), 183 ...
# ..                                                ...
# 95  [Παναγή Τσαλδάρη 261-263 (Ιατρίδου), 176 75 Κα...
# 96  [Τζον Κένεντι, 182 33 Άγιος Ιωάννης Ρέντης, Ατ...
# 97  [Δοϊράνης 238-242, 176 74 Καλλιθέα, Αττική, Ελ...
# 98  [Ελευθερίου Βενιζέλου 216, 176 75 Καλλιθέα, Ατ...
# 99  [Ακτή Κουμουνδούρου 1 (Μικρολιμανο), 185 33 Πε...
#
#                                      venue.categories venue.photos.count  \
# 0   [{'id': '53d6c1b0e4b02351e88a83d8', 'name': 'F...                  0
# 1   [{'id': '4bf58dd8d48988d10e941735', 'name': 'G...                  0
# 2   [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...                  0
# 3   [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...                  0
# 4   [{'id': '52e81612bcbc57f1066b79f3', 'name': 'S...                  0
# ..                                                ...                ...
# 95  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...                  0
# 96  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...                  0
# 97  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...                  0
# 98  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...                  0
# 99  [{'id': '4bf58dd8d48988d10e941735', 'name': 'G...                  0
#
#     venue.photos.groups venue.location.neighborhood venue.venuePage.id
# 0                    []                         NaN                NaN
# 1                    []                         NaN                NaN
# 2                    []                         NaN                NaN
# 3                    []                         NaN                NaN
# 4                    []                         NaN                NaN
# ..                  ...                         ...                ...
# 95                   []                         NaN                NaN
# 96                   []        Άγιος Ιωάννης Ρέντης                NaN
# 97                   []                         NaN                NaN
# 98                   []                         NaN                NaN
# 99                   []                         NaN                NaN
#
# [100 rows x 21 columns]

# %% [markdown]
# After carefully inspecting the results, there are places that do not really fit in. These are coffee shops or restaurants that mainly serve meat plates. To clean up the resulting set we will create a set of accepted keywords that should appear under the 'venue.categories' column.

# %%
# Clean up results
accepted_keywords = ['Mediterranean', 'Greek', 'Cretan', 'Meze', 'Tsipouro', 'Seafood', 'Fish', 'Magirio']
for i, row in df.iterrows():
    categ = row['venue.categories'][0]['name']
    accepted = any(accepted_keyword in categ for accepted_keyword in accepted_keywords)
    if not accepted:
        df.drop([i], inplace=True)
        
# Reindex rows after clean up
df.reset_index(drop=True, inplace=True)

# Rename columns
df.rename(columns = {'venue.id':'id', 'venue.name':'name', 'venue.location.formattedAddress':'address', 'venue.location.lat':'lat', 'venue.location.lng':'lng'}, inplace = True) 

# Select only columns of interest
dff = df[['id', 'name', 'address', 'lat', 'lng']]

dff
# Out:
#                           id                          name  \
# 0   513b9171e4b0dd4603da018f                   Ψαρομεζέδες
# 1   4ccc7c39ee23a14395751fa8                       Ο Βόλος
# 2   4d1a5b038e4c548112f84abc                       Άργουρα
# 3   4b6dc50df964a5202e8e2ce3                    Τα κανάρια
# 4   5512fe78498ef8fef56cc2ac                L'Ovelha Negra
# 5   4cf107fe7e0da1cd6a098f97                  Το Ζεμπερέκι
# 6   50e73a94e4b0531aceb291bb                      Αλισμαρί
# 7   4d13c4d025cda143dde15ad6           Ψαρομεζέδες Αντωνία
# 8   5234b30511d25bafc84d52e5                       Ολυμπία
# 9   4c9b81b878ffa0933cb37575                      Λευτέρης
# 10  51a4ab87498e9aef442c45c5           Green Μάνη Catering
# 11  54822114498e10f299961dea                        Ομαλός
# 12  4d53f6e6b3d9a35dec48c87b                      Πατούχας
# 13  5346ecc3498e451f8db5f5a9               Γιαγιά Ελισάβετ
# 14  4d6021ecef378cfa8f6279a6                    Εν Μοσχάτω
# 15  50828d2ee4b0f99e5b0e5f44                     Ρακί Μεζέ
# 16  4eaef721e30009a543bd5131  Ζωοδόχος Πηγή Οινομαγειρείον
# 17  4befe69d51f2c9b685fbf092                    Δουράμπεης
# 18  51f13b4a498e3f0f6d06e3e4                      Κρίταμος
# 19  4c402d52af052d7f84617b79                       Ντογάκι
# 20  5740b005498eb87fd2daf254                  Στου Μέρτηκα
# 21  4ff4991de4b0fe7c1ffc3a78                    Ο Πεζούλας
# 22  4dd158c9d4c065592fc3f9b0               Γιαγιά Ελισάβετ
# 23  5499bcd2498e9fa6ce662873                     Ρακογωνία
# 24  4dea3d4122713dd9738d2afa         Το Καπηλειό του Ζάχου
# 25  4e724fee1f6ecfe82c351f2e                 Τα Μεζεκλίκια
# 26  58512c4d2f91cb0863e19602                          Mira
# 27  5c56e72e6fd626002c7e842d                       Stalati
# 28  4d4d7798d6f3224b875d9ca6               Κακαβιά ο Νίκος
# 29  5184010c498ed4872e62d1f9                         Ελιές
# 30  4f887772e4b0a95f9301c007                   Αλατοπίπερο
# 31  5304ef72498e27dd55a52207                     Ο Βασίλης
# 32  4f847989e4b0f13eb583e13c                    Μπούσουλας
# 33  4e6a6275483bf2d9e63476ac                    Θαλασσινός
# 34  4fd09d5de4b0d89b2442ce43       Οινομαγειρείο Αμέθυστος
# 35  4b5a1ddcf964a52048ae28e3                       Οινοθόη
# 36  4cae2ca239458cfa8551f09f                   Το Κουτούκι
# 37  4e1c971aae605fbe03862093                    Το "Στέκι"
# 38  4d248955daa93704c83ac681        Οι γεύσεις του Διογένη
# 39  4ce57e6919efa09397bac5f1                       Zorba's
# 40  4e0390dad4c07481580f47b8                     Ψαροπουλα
# 32       [Σάμου 16 (Ζανέτου), 185 41 Καμίνια, Ελλάδα]  37.953447  23.659757
# 33  [Λυσικράτους 32 (Ηρακλέους), 176 74 Καλλιθέα, ...  37.943905  23.694940
# 34  [Λευκωσίας 1 & Αγγελοπούλου, 185 41 Καμίνια, Ε...  37.955200  23.659158
# 35  [Κωνσταντινουπόλεως 91 (Σερρών), 183 45 Μοσχάτ...  37.951483  23.674781
# 36  [Μακρυγιάννη 113, 183 45 Μοσχάτο, Αττική, Ελλάδα]  37.953071  23.679084
# 37                                           [Ελλάδα]  37.953772  23.679615
# 38  [Πεντέλης 25 (Υμηττού), 175 64 Παλαιό Φάληρο, ...  37.941840  23.699038
# 39  [Ακτή Κουμουνδούρου 14, 185 33 Πειραιάς, Αττικ...  37.938613  23.660765
# 40          [Sokratous 237, Καλλιθέα, Αττική, Ελλάδα]  37.943582  23.696338
# 41  [Λεωφ. Ελευθερίου Βενιζέλου 243, 176 73 Καλλιθ...  37.951607  23.694646
# 42  [Ακτή Κουμουνδούρου 12, 185 33 Πειραιάς, Αττικ...  37.938690  23.661123
# 43  [Παναγή Τσαλδάρη 261, 176 75 Καλλιθέα, Αττική,...  37.957109  23.694260
# 44  [Ακτή Κουμουνδούρου 1 (Μικρολιμανο), 185 33 Πε...  37.938035  23.661673
#
#     score
# 0    0.86
# 1    2.08
# 2    1.06
# 3    3.17
# 4    2.29
# 5    0.36
# 6    3.46
# 7    4.62
# 8    1.24
# 9    4.14
# 10   2.34
# 11   1.12
# 12   0.93
# 13   1.10
# 14   3.06
# 15   4.06
# 16   2.36
# 17   1.03
# 18   4.37
# 19   0.94
# 20   0.33
# 21   1.88
# 22   4.52
# 23   2.72
# 24   0.57
# 25   2.62
# 26   4.64
# 27   4.26
# 28   0.13
# 29   2.73
# 30   0.40
# 31   2.27
# 32   3.49
# 33   1.58
# 34   1.13
# 35   0.35
# 36   3.63
# 37   1.26
# 38   2.51
# 39   1.30
# 40   0.94
# 41   4.54
# 42   2.95
# 43   2.96
# 44   3.02

# %% [markdown]
# For our map we will use red markers for restaurants that have a rating greater than 4/5. Also, we will use opacity to show areas that are covered by more than one restaurants.

# %%
# generate map centered to our location
venues_map = folium.Map(location=[latitude, longitude], zoom_start=14)

# add venues
for i, row in dff.iterrows():

    strength = round(row['score'] / 5, 2)
    if strength > 0.8:
        mcolor = "Crimson"
    else:
        mcolor = "DarkSlateBlue"

    folium.CircleMarker(
        [row['lat'], row['lng']],
        radius = 50,
        color = "#CCC",
        popup = str(i) + ': ' + str(row['score']),
        fill = True,
        fill_color = mcolor,
        fill_opacity = strength,
        opacity = 1
    ).add_to(venues_map)

# add a red marker for Moschato
folium.CircleMarker(
    [latitude, longitude],
    radius = 10,
    color = 'white',
    fill = True,
    fill_color = 'red',
    fill_opacity = 1
).add_to(venues_map)
        
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# By examining the map we can easily identify potential areas for our new seafood reastaurant in Moschato.
