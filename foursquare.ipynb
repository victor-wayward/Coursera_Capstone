# %%
import requests        # library to handle requests
import pandas as pd    # library for data analsysis
import numpy as np     # library to handle data in a vectorized manner
import random          # library for random number generation
import folium          # plotting library

from geopy.geocoders import Nominatim       # module to convert an address into latitude and longitude values
from IPython.display import Image           # libraries for displaying images
from IPython.core.display import HTML 

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
CLIENT_ID = 'VVYPVIUVG44L3HD4NBFEGWZWEL2SNZLS2FSU4FN5KMWHTT3A'
CLIENT_SECRET = 'BIQ3R1HDU5Z2GL25TLDAPPP1BAWKBNPODJJAUMOR0PI4PWIZ'
ACCESS_TOKEN = ''
VERSION = '20201201'
LIMIT = 100

print('Credentials:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Credentials:
# CLIENT_ID: VVYPVIUVG44L3HD4NBFEGWZWEL2SNZLS2FSU4FN5KMWHTT3A
# CLIENT_SECRET:BIQ3R1HDU5Z2GL25TLDAPPP1BAWKBNPODJJAUMOR0PI4PWIZ

# %%
area = 'Moschato, Athens, Attica, Greece'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 37.9535099 23.681799

# %%
search_query = 'seafood'
search_cat = '4bf58dd8d48988d1ce941735'
radius = 1000

url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&section=food&categoryId={}&radius={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, ACCESS_TOKEN, VERSION, search_cat, radius)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=VVYPVIUVG44L3HD4NBFEGWZWEL2SNZLS2FSU4FN5KMWHTT3A&client_secret=BIQ3R1HDU5Z2GL25TLDAPPP1BAWKBNPODJJAUMOR0PI4PWIZ&ll=37.9535099,23.681799&oauth_token=&v=20201201&section=food&categoryId=4bf58dd8d48988d1ce941735&radius=1000'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5fcea72cb1c42f0105ae861a'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Moschato',
#   'headerFullLocation': 'Moschato, Athens',
#   'headerLocationGranularity': 'neighborhood',
#   'query': 'food',
#   'totalResults': 70,
#   'suggestedBounds': {'ne': {'lat': 37.96250990900001,
#     'lng': 23.693191632229272},
#    'sw': {'lat': 37.94450989099999, 'lng': 23.67040636777073}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ccc7c39ee23a14395751fa8',
#        'name': 'Ο Βόλος',
#        'location': {'address': 'Πλάτωνος 110',
#         'lat': 37.95096101404494,
#         'lng': 23.683292213861613,
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['groups']['recommended']['items']

# tranform venues into a dataframe
df = pd.json_normalize(venues)
display(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-b28aa5cca011> in <module>
#       1 # assign relevant part of JSON to venues
# ----> 2 venues = results['response']['groups']['recommended']['items']
#       3
#       4 # tranform venues into a dataframe
#       5 df = pd.json_normalize(venues)
#
# TypeError: list indices must be integers or slices, not str

# %%
# generate map centered at our location
venues_map = folium.Map(location=[latitude, longitude], zoom_start=10)

# add a red marker to represent home
folium.CircleMarker(
    [latitude, longitude],
    radius=8,
    color='red',
    popup='Home',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add coffee shops
for index, row in df.iterrows():
    folium.CircleMarker(
        [row['location.lat'], row['location.lng']],
        radius=5,
        color='blue',
        popup=row['name'],
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)
        
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
